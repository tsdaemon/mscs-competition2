# %%
import pandas as pd
pd.set_option('display.max_columns', None)
vals = pd.read_csv("./data/features/all_media_info.csv", encoding='utf8')
vals.head()
# Out:
# C:\Users\Anatoliy\Anaconda2\envs\py35\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Id                    Title               TitleShort TitleVersion  \
# 0  311270    Les hommes de la Paix    Les hommes de la Paix          NaN
# 1  315013               Le Recyclé               Le Recyclé          NaN
# 2  237198             Caressé moin             Caressé moin          NaN
# 3  518120  Station and other place  Station and other place          NaN
# 4  597708       Le sucre et le sel       Le sucre et le sel          NaN
#
#            Isrc                                 Link  Duration  TrackPosition  \
# 0  FR6V80627011  https://www.deezer.com/track/311270     291.0            7.0
# 1  FRP4P0600100  https://www.deezer.com/track/315013     230.0           10.0
# 2  FR6V80402545  https://www.deezer.com/track/237198     335.0            5.0
# 3  FR6V80800863  https://www.deezer.com/track/518120     219.0            1.0
# 4  CAC220300117  https://www.deezer.com/track/597708     233.0            9.0
#
#    DiskNumber      Rank ExplicitLyrics  \
# 0         1.0  343460.0          False
# 1         1.0  276157.0          False
# 2         1.0  359138.0          False
# 3         1.0  308744.0          False
# 4         1.0  292680.0          False
#
#                                              Preview    Bpm  Gain  \
# 0  http://e-cdn-preview-e.deezer.com/stream/e4312...  142.1 -14.9
# 1  http://e-cdn-preview-c.deezer.com/stream/cc7db...   97.0  -9.6
# 2  http://e-cdn-preview-b.deezer.com/stream/b1d13...  180.5  -9.6
# 3  http://e-cdn-preview-d.deezer.com/stream/d9d65...  136.0  -9.9
# 4  http://e-cdn-preview-b.deezer.com/stream/b44d8...  166.0 -10.8
#
#   Isrc_Country Isrc_Label
# 0           FR        6V8
# 1           FR        P4P
# 2           FR        6V8
# 3           FR        6V8
# 4           CA        C22

# %%
vals['Isrc_Country'] = vals['Isrc'].str.slice(0,2)
vals['Isrc_Label'] = vals['Isrc'].str.slice(2,5)
vals.head()
# Out:
#        Id                    Title               TitleShort TitleVersion  \
# 0  311270    Les hommes de la Paix    Les hommes de la Paix          NaN
# 1  315013               Le Recyclé               Le Recyclé          NaN
# 2  237198             Caressé moin             Caressé moin          NaN
# 3  518120  Station and other place  Station and other place          NaN
# 4  597708       Le sucre et le sel       Le sucre et le sel          NaN
#
#            Isrc                                 Link  Duration  TrackPosition  \
# 0  FR6V80627011  https://www.deezer.com/track/311270     291.0            7.0
# 1  FRP4P0600100  https://www.deezer.com/track/315013     230.0           10.0
# 2  FR6V80402545  https://www.deezer.com/track/237198     335.0            5.0
# 3  FR6V80800863  https://www.deezer.com/track/518120     219.0            1.0
# 4  CAC220300117  https://www.deezer.com/track/597708     233.0            9.0
#
#    DiskNumber      Rank ExplicitLyrics  \
# 0         1.0  343460.0          False
# 1         1.0  276157.0          False
# 2         1.0  359138.0          False
# 3         1.0  308744.0          False
# 4         1.0  292680.0          False
#
#                                              Preview    Bpm  Gain  \
# 0  http://e-cdn-preview-e.deezer.com/stream/e4312...  142.1 -14.9
# 1  http://e-cdn-preview-c.deezer.com/stream/cc7db...   97.0  -9.6
# 2  http://e-cdn-preview-b.deezer.com/stream/b1d13...  180.5  -9.6
# 3  http://e-cdn-preview-d.deezer.com/stream/d9d65...  136.0  -9.9
# 4  http://e-cdn-preview-b.deezer.com/stream/b44d8...  166.0 -10.8
#
#   Isrc_Country Isrc_Label
# 0           FR        6V8
# 1           FR        P4P
# 2           FR        6V8
# 3           FR        6V8
# 4           CA        C22

# %%
vals.to_csv("./data/features/all_media_info.csv", encoding='utf8', index=False)

# %% [markdown]
# ------

# %%
import pandas as pd

path_to_train = './data/train.csv'
path_to_test = './data/test.csv'

train = pd.read_csv(path_to_train, encoding='utf-8', usecols=['user_id', 'media_id', 'is_listened'])
test = pd.read_csv(path_to_test, encoding='utf-8', usecols=['user_id', 'media_id'])
test['is_listened'] = 0

df = pd.concat([train, test], ignore_index=True)
df.tail()
# Out:
#           media_id  user_id  is_listened
# 7578747  133549164    12641            0
# 7578748  133549164    10055            0
# 7578749  136334560     1029            0
# 7578750  136334560     4630            0
# 7578751  136334560     6467            0

# %%
path_to_track_data = './data/features/all_media_info.csv'
track_info = pd.read_csv(path_to_track_data, encoding='utf-8', usecols=['Id', 'TrackPosition', 'DiskNumber', 'Rank', 'Rank', 'ExplicitLyrics', 'Bpm', 'Gain', 'Isrc', 'Isrc_Country', 'Isrc_Label'])
track_info.head()
# Out:
# C:\Users\Anatoliy\Anaconda2\envs\py35\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Id          Isrc  TrackPosition  DiskNumber      Rank ExplicitLyrics  \
# 0  311270  FR6V80627011            7.0         1.0  343460.0          False
# 1  315013  FRP4P0600100           10.0         1.0  276157.0          False
# 2  237198  FR6V80402545            5.0         1.0  359138.0          False
# 3  518120  FR6V80800863            1.0         1.0  308744.0          False
# 4  597708  CAC220300117            9.0         1.0  292680.0          False
#
#      Bpm  Gain Isrc_Country Isrc_Label
# 0  142.1 -14.9           FR        6V8
# 1   97.0  -9.6           FR        P4P
# 2  180.5  -9.6           FR        6V8
# 3  136.0  -9.9           FR        6V8
# 4  166.0 -10.8           CA        C22

# %%
df_joined = df.merge(track_info, how='left', left_on='media_id', right_on='Id')
del df_joined['Id']
df_joined.head()
# Out:
#    media_id  user_id  is_listened          Isrc  TrackPosition  DiskNumber  \
# 0    222606     9241            0  FR6V80400860           10.0         1.0
# 1    250467    16547            1  FR6V80405714            4.0         1.0
# 2    305197     7665            1  FR6V88900849            1.0         1.0
# 3    900502     1580            0  NLA200000110           11.0         1.0
# 4    542335     1812            1  USSM16501030            1.0         1.0
#
#        Rank ExplicitLyrics    Bpm  Gain Isrc_Country Isrc_Label
# 0  292784.0          False  100.1 -10.3           FR        6V8
# 1  317348.0          False  160.2  -9.9           FR        6V8
# 2  309034.0          False   90.1 -17.7           FR        6V8
# 3  291331.0          False  124.9  -8.7           NL        A20
# 4  406872.0          False  120.0 -12.5           US        SM1

# %%
len(df_joined[df_joined['Bpm'].isnull()])
# Out:
# 512

# %%
df_joined[df_joined['Gain'].notnull()][df_joined['Gain'].convert_objects(convert_numeric=True).isnull()]
# Out:
# C:\Users\Anatoliy\Anaconda2\envs\py35\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# C:\Users\Anatoliy\Anaconda2\envs\py35\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# Empty DataFrame
# Columns: [media_id, user_id, is_listened, Isrc, TrackPosition, DiskNumber, Rank, ExplicitLyrics, Bpm, Gain, Isrc_Country, Isrc_Label]
# Index: []

# %%
df_joined['TrackPosition'] = df_joined['TrackPosition'].fillna(df_joined['TrackPosition'].mean())
df_joined['DiskNumber'] = df_joined['DiskNumber'].fillna(1)
df_joined['Rank'] = df_joined['Rank'].fillna(df_joined['Rank'].mean())
df_joined['ExplicitLyrics'] = df_joined['ExplicitLyrics'].fillna(False)
df_joined['Bpm'] = df_joined['Bpm'].fillna(df_joined['Bpm'].mean())
df_joined['Gain'] = df_joined['Gain'].fillna(df_joined['Gain'].mean())
df_joined['Isrc_Country'] = df_joined['Isrc_Country'].fillna("unk").map(str)
df_joined['Isrc_Label'] = df_joined['Isrc_Label'].fillna("unk").map(str)
df_joined[df_joined['Isrc_Country'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [media_id, user_id, is_listened, Isrc, TrackPosition, DiskNumber, Rank, ExplicitLyrics, Bpm, Gain, Isrc_Country, Isrc_Label]
# Index: []

# %%
from sklearn import preprocessing
le_country = preprocessing.LabelEncoder()
le_country.fit(df_joined['Isrc_Country'])
df_joined['Isrc_Country'] = le_country.transform(df_joined['Isrc_Country'])

le_lyrics = preprocessing.LabelEncoder()
le_lyrics.fit(df_joined['ExplicitLyrics'])
df_joined['ExplicitLyrics'] = le_lyrics.transform(df_joined['ExplicitLyrics'])

le_label = preprocessing.LabelEncoder()
le_label.fit(df_joined['Isrc_Label'])
df_joined['Isrc_Label'] = le_label.transform(df_joined['Isrc_Label'])
df_joined.head()
# Out:
#    media_id  user_id  is_listened          Isrc  TrackPosition  DiskNumber  \
# 0    222606     9241            0  FR6V80400860           10.0         1.0
# 1    250467    16547            1  FR6V80405714            4.0         1.0
# 2    305197     7665            1  FR6V88900849            1.0         1.0
# 3    900502     1580            0  NLA200000110           11.0         1.0
# 4    542335     1812            1  USSM16501030            1.0         1.0
#
#        Rank  ExplicitLyrics    Bpm  Gain  Isrc_Country  Isrc_Label
# 0  292784.0               0  100.1 -10.3            54        2091
# 1  317348.0               0  160.2  -9.9            54        2091
# 2  309034.0               0   90.1 -17.7            54        2091
# 3  291331.0               0  124.9  -8.7           106        2925
# 4  406872.0               0  120.0 -12.5           145        8228

# %%
del df_joined['Isrc']

# %%
by_user_mean = df_joined[df_joined['is_listened']==1].groupby('user_id', as_index=False).agg({'Bpm':'mean', 'Gain':'mean'})
by_user_mean.head()
# Out:
#    user_id         Bpm       Gain
# 0        0  118.968509 -10.009290
# 1        1  119.150188 -10.479189
# 2        2  123.398457  -9.960308
# 3        3  127.367065 -11.012104
# 4        4  117.064893  -8.140530

# %%
len(by_user_mean), len(df_joined['user_id'].unique())
# Out:
# (19716, 19918)

# %%
df_joined = df_joined.join(by_user_mean, how='left', on='user_id', rsuffix='ByUserMean')
del df_joined['user_idByUserMean']
df_joined['GainByUserMean'].fillna(df_joined['Gain'].mean())
df_joined['BpmByUserMean'].fillna(df_joined['Bpm'].mean())
df_joined.head()
# Out:
#    media_id  user_id  is_listened  TrackPosition  DiskNumber      Rank  \
# 0    222606     9241            0           10.0         1.0  292784.0
# 1    250467    16547            1            4.0         1.0  317348.0
# 2    305197     7665            1            1.0         1.0  309034.0
# 3    900502     1580            0           11.0         1.0  291331.0
# 4    542335     1812            1            1.0         1.0  406872.0
#
#    ExplicitLyrics    Bpm  Gain  Isrc_Country  Isrc_Label  BpmByUserMean  \
# 0               0  100.1 -10.3            54        2091     122.356478
# 1               0  160.2  -9.9            54        2091     122.514286
# 2               0   90.1 -17.7            54        2091     124.553876
# 3               0  124.9  -8.7           106        2925     121.802594
# 4               0  120.0 -12.5           145        8228     123.736146
#
#    GainByUserMean
# 0      -11.257516
# 1       -8.946429
# 2      -11.481208
# 3       -8.284311
# 4       -9.279614

# %%
df_joined['GainCenter'] = df_joined['Gain'] - df_joined['GainByUserMean']
df_joined['BpmCenter'] = df_joined['Bpm'] - df_joined['BpmByUserMean']
df_joined.head()
# Out:
#    media_id  user_id  is_listened  TrackPosition  DiskNumber      Rank  \
# 0    222606     9241            0           10.0         1.0  292784.0
# 1    250467    16547            1            4.0         1.0  317348.0
# 2    305197     7665            1            1.0         1.0  309034.0
# 3    900502     1580            0           11.0         1.0  291331.0
# 4    542335     1812            1            1.0         1.0  406872.0
#
#    ExplicitLyrics    Bpm  Gain  Isrc_Country  Isrc_Label  BpmByUserMean  \
# 0               0  100.1 -10.3            54        2091     122.356478
# 1               0  160.2  -9.9            54        2091     122.514286
# 2               0   90.1 -17.7            54        2091     124.553876
# 3               0  124.9  -8.7           106        2925     121.802594
# 4               0  120.0 -12.5           145        8228     123.736146
#
#    GainByUserMean  GainCenter  BpmCenter
# 0      -11.257516    0.957516 -22.256478
# 1       -8.946429   -0.953571  37.685714
# 2      -11.481208   -6.218792 -34.453876
# 3       -8.284311   -0.415689   3.097406
# 4       -9.279614   -3.220386  -3.736146

# %%
by_user_country = df_joined[df_joined['is_listened']==1].groupby(['user_id', 'Isrc_Country'], as_index=False).agg({'media_id':'count'})
by_user_country['Isrc_Country_count'] = by_user_country['media_id']
del by_user_country['media_id']
by_user_country.head()
# Out:
#    user_id  Isrc_Country  Isrc_Country_count
# 0        0            13                  15
# 1        0            15                 120
# 2        0            16                  55
# 3        0            20                  60
# 4        0            24                   7

# %%
df_joined2 = df_joined.merge(by_user_country, how='left', on=['user_id', 'Isrc_Country'])
df_joined2.head()
# Out:
#    media_id  user_id  is_listened  TrackPosition  DiskNumber      Rank  \
# 0    222606     9241            0           10.0         1.0  292784.0
# 1    250467    16547            1            4.0         1.0  317348.0
# 2    305197     7665            1            1.0         1.0  309034.0
# 3    900502     1580            0           11.0         1.0  291331.0
# 4    542335     1812            1            1.0         1.0  406872.0
#
#    ExplicitLyrics    Bpm  Gain  Isrc_Country  Isrc_Label  BpmByUserMean  \
# 0               0  100.1 -10.3            54        2091     122.356478
# 1               0  160.2  -9.9            54        2091     122.514286
# 2               0   90.1 -17.7            54        2091     124.553876
# 3               0  124.9  -8.7           106        2925     121.802594
# 4               0  120.0 -12.5           145        8228     123.736146
#
#    GainByUserMean  GainCenter  BpmCenter  Isrc_Country_count
# 0      -11.257516    0.957516 -22.256478                89.0
# 1       -8.946429   -0.953571  37.685714                18.0
# 2      -11.481208   -6.218792 -34.453876                32.0
# 3       -8.284311   -0.415689   3.097406                 2.0
# 4       -9.279614   -3.220386  -3.736146               349.0

# %%
by_user = df_joined[df_joined['is_listened']==1].groupby('user_id', as_index=False).agg({'media_id':'count'})
by_user['Count'] = by_user['media_id']
del by_user['media_id']
by_user.head()
df_joined3 = df_joined2.merge(by_user, how='left', on='user_id')
df_joined3.head()
# Out:
#    media_id  user_id  is_listened  TrackPosition  DiskNumber      Rank  \
# 0    222606     9241            0           10.0         1.0  292784.0
# 1    250467    16547            1            4.0         1.0  317348.0
# 2    305197     7665            1            1.0         1.0  309034.0
# 3    900502     1580            0           11.0         1.0  291331.0
# 4    542335     1812            1            1.0         1.0  406872.0
#
#    ExplicitLyrics    Bpm  Gain  Isrc_Country  Isrc_Label  BpmByUserMean  \
# 0               0  100.1 -10.3            54        2091     122.356478
# 1               0  160.2  -9.9            54        2091     122.514286
# 2               0   90.1 -17.7            54        2091     124.553876
# 3               0  124.9  -8.7           106        2925     121.802594
# 4               0  120.0 -12.5           145        8228     123.736146
#
#    GainByUserMean  GainCenter  BpmCenter  Isrc_Country_count  Count
# 0      -11.257516    0.957516 -22.256478                89.0  153.0
# 1       -8.946429   -0.953571  37.685714                18.0   23.0
# 2      -11.481208   -6.218792 -34.453876                32.0  298.0
# 3       -8.284311   -0.415689   3.097406                 2.0  631.0
# 4       -9.279614   -3.220386  -3.736146               349.0  932.0

# %%
df_joined3['Isrc_Country_count'] = df_joined3['Isrc_Country_count']/df_joined3['Count']

# %%
path_to_api_track_data_train = './data/features/api_data_track.train.txt'
path_to_api_track_data_test = './data/features/api_data_track.test.txt'

newcols = ['TrackPosition','DiskNumber','Rank','ExplicitLyrics', 
           'Bpm','Gain', 'Isrc_Country','Isrc_Label','BpmByUserMean',
           'GainByUserMean','GainCenter', 'BpmCenter', 'Isrc_Country_count']

# %%
train_dt = df_joined3.loc[range(len(train))][newcols]
train_dt.to_csv(path_to_api_track_data_train, encoding='utf-8', index=False)

test_dt = df_joined3.loc[range(len(train), len(train)+len(test))][newcols]
test_dt.to_csv(path_to_api_track_data_test, encoding='utf-8', index=False)

# %% [markdown]
# -----

# %%
import validation as v
import pandas as pd

path_to_train = './data/train.csv'

train = pd.read_csv(path_to_train, encoding='utf-8')

train = pd.concat([train, pd.read_csv(path_to_api_track_data_train, encoding='utf-8')], axis=1)
#train = train[train['is_listened']==1]
train.head()
# Out:
#    genre_id   ts_listen  media_id  album_id  context_type  release_date  \
# 1     25571  1480544735    250467     43941             0      20060301
# 2        16  1479563953    305197     48078             1      20140714
# 4         7  1478368974    542335     71718             0      20080215
# 5         7  1478382544    542335     71718             0      20080215
# 6         7  1478338409    542335     71718             0      20080215
#
#    platform_name  platform_family  media_duration  listen_type  \
# 1              2                1             171            0
# 2              2                1             149            1
# 4              0                0             150            0
# 5              0                0             150            0
# 6              0                0             150            0
#
#           ...          ExplicitLyrics    Bpm  Gain  Isrc_Country  Isrc_Label  \
# 1         ...                       0  160.2  -9.9            54        2091
# 2         ...                       0   90.1 -17.7            54        2091
# 4         ...                       0  120.0 -12.5           145        8228
# 5         ...                       0  120.0 -12.5           145        8228
# 6         ...                       0  120.0 -12.5           145        8228
#
#    BpmByUserMean  GainByUserMean  GainCenter  BpmCenter  Isrc_Country_count
# 1     122.514286       -8.946429   -0.953571  37.685714            0.782609
# 2     124.553876      -11.481208   -6.218792 -34.453876            0.107383
# 4     123.736146       -9.279614   -3.220386  -3.736146            0.374464
# 5     123.736146       -9.279614   -3.220386  -3.736146            0.374464
# 6     123.736146       -9.279614   -3.220386  -3.736146            0.374464
#
# [5 rows x 28 columns]

# %%
path_to_folds = './data/lightgbm/api'

# %%
v.generate_validation_folds(train, path_to_folds)
# Out:
# Fold 1

# %%
import model_lgbm as mlgbm

cols = [
        'genre_id', 'media_id', 'album_id', 'context_type',
        'release_date', 'platform_name', 'platform_family', 'media_duration',
        'listen_type', 'user_gender', 'user_id', 'artist_id', 'user_age', 
       ] + newcols

params = {
    'application':'binary',
    'num_leaves': 20,
    'max_depth': 15,
    'feature_fraction': 0.7,
    'bagging_fraction': 0.7,
    'max_bin': 20,
    'metric': 'auc',
    'verbose': 1
}

# %%
evs = mlgbm.crossvalidate_model(path_to_folds,cols,params,validate_on_both=True)
# Out:
# [1]	training's auc: 1	valid_1's auc: 1
# [2]	training's auc: 1	valid_1's auc: 1
# [3]	training's auc: 1	valid_1's auc: 1
# [4]	training's auc: 1	valid_1's auc: 1
# [5]	training's auc: 1	valid_1's auc: 1
# [6]	training's auc: 1	valid_1's auc: 1
# [7]	training's auc: 1	valid_1's auc: 1
# [8]	training's auc: 1	valid_1's auc: 1
# [9]	training's auc: 1	valid_1's auc: 1
# [10]	training's auc: 1	valid_1's auc: 1
# [11]	training's auc: 1	valid_1's auc: 1
# [12]	training's auc: 1	valid_1's auc: 1
# [13]	training's auc: 1	valid_1's auc: 1
# [576]	training's auc: 1	valid_1's auc: 1
# [577]	training's auc: 1	valid_1's auc: 1
# [578]	training's auc: 1	valid_1's auc: 1
# [579]	training's auc: 1	valid_1's auc: 1
# [580]	training's auc: 1	valid_1's auc: 1
# [581]	training's auc: 1	valid_1's auc: 1
# [582]	training's auc: 1	valid_1's auc: 1
# [583]	training's auc: 1	valid_1's auc: 1
# [584]	training's auc: 1	valid_1's auc: 1
# [585]	training's auc: 1	valid_1's auc: 1
# [586]	training's auc: 1	valid_1's auc: 1
# [587]	training's auc: 1	valid_1's auc: 1
# [588]	training's auc: 1	valid_1's auc: 1
# [589]	training's auc: 1	valid_1's auc: 1
# [590]	training's auc: 1	valid_1's auc: 1
# [591]	training's auc: 1	valid_1's auc: 1
# [592]	training's auc: 1	valid_1's auc: 1
# [593]	training's auc: 1	valid_1's auc: 1
# [594]	training's auc: 1	valid_1's auc: 1
# [595]	training's auc: 1	valid_1's auc: 1
# [596]	training's auc: 1	valid_1's auc: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-ee6324307edb> in <module>()
# ----> 1 evs = mlgbm.crossvalidate_model(path_to_folds,cols,params,validate_on_both=True)
#
# /media/windows_d/DRIVE/MS CS UCU/DataScienceGame/model_lgbm.py in crossvalidate_model(path_to_folds, cols, params, verbose, iterations, validate_on_both)
#      17         if(validate_on_both):
#      18             validation = [lgb_train,lgb_test]
# ---> 19         model_lgm = lgb.train(params, lgb_train, iterations, valid_sets=validation, verbose_eval=verbose, evals_result=evals)
#      20         if(verbose):
#      21             print(evals["valid_0"]["auc"][-1])
#
# /home/tsdaemon/anaconda3/lib/python3.6/site-packages/lightgbm-0.1-py3.6.egg/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, callbacks)
#     184         if valid_sets is not None:
#     185             if is_valid_contain_train:
# --> 186                 evaluation_result_list.extend(booster.eval_train(feval))
#     187             evaluation_result_list.extend(booster.eval_valid(feval))
#     188         try:
#
# /home/tsdaemon/anaconda3/lib/python3.6/site-packages/lightgbm-0.1-py3.6.egg/lightgbm/basic.py in eval_train(self, feval)
#    1453             Evaluation result list.
#    1454         """
# -> 1455         return self.__inner_eval(self.__train_data_name, 0, feval)
#    1456
#    1457     def eval_valid(self, feval=None):
#
# /home/tsdaemon/anaconda3/lib/python3.6/site-packages/lightgbm-0.1-py3.6.egg/lightgbm/basic.py in __inner_eval(self, data_name, data_idx, feval)
#    1680                 ctypes.c_int(data_idx),
#    1681                 ctypes.byref(tmp_out_len),
# -> 1682                 result.ctypes.data_as(ctypes.POINTER(ctypes.c_double))))
#    1683             if tmp_out_len.value != self.__num_inner_eval:
#    1684                 raise ValueError("Wrong length of eval results")
#
# KeyboardInterrupt:

# %%
import pandas as pd

path_to_sample = './data/sample_submission_kaggle.csv'
path_to_submission = './data/submission.csv'
path_to_test = './data/test.csv'

test = pd.read_csv(path_to_test, encoding='utf-8')
test = pd.concat([test, pd.read_csv(path_to_api_track_data_test, encoding='utf-8')], axis=1)

test.head()
# Out:
#    sample_id  genre_id   ts_listen  media_id  album_id  context_type  \
# 0          0        50  1478104371    683078     82356             1
# 1          1      2744  1479317140    876497     99692             1
# 2          2      2744  1479546361    876497     99692             1
# 3          3      2744  1478457729    876500     99692             1
# 4          4      2744  1480448560    876504     99692             1
#
#    release_date  platform_name  platform_family  media_duration  \
# 0      20021008              0                0             542
# 1      19851231              0                0             307
# 2      19851231              0                0             307
# 3      19851231              2                1             265
# 4      19851231              2                1             356
#
#           ...          ExplicitLyrics    Bpm  Gain  Isrc_Country  Isrc_Label  \
# 0         ...                       0  181.0 -11.2            54        1208
# 1         ...                       0   88.0 -15.1            54        9684
# 2         ...                       0   88.0 -15.1            54        9684
# 3         ...                       0  107.0 -16.2            54        9684
# 4         ...                       0  110.0 -16.3            54        9684
#
#    BpmByUserMean  GainByUserMean  GainCenter  BpmCenter  Isrc_Country_count
# 0     127.640584       -9.052632   -2.147368  53.359416            0.240000
# 1     138.024395       -8.166901   -6.933099 -50.024395            0.372263
# 2     125.741566      -10.710046   -4.389954 -37.741566            0.639269
# 3     130.469657       -9.994161   -6.205839 -23.469657            0.686131
# 4     124.394607      -11.375735   -4.924265 -14.394607            0.761029
#
# [5 rows x 28 columns]

# %%
import model_lgbm as mlgbm
fs = mlgbm.create_submission(train, test, path_to_sample, params, cols, path_to_submission, iterations=600)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-34d0c7202038> in <module>()
#       1 import model_lgbm as mlgbm
# ----> 2 fs = mlgbm.create_submission(train, test, path_to_sample, params, cols, path_to_submission, iterations=600)
#
# /media/windows_d/DRIVE/MS CS UCU/DataScienceGame/model_lgbm.py in create_submission(train, test, path_to_sample_submission, params, cols, path_to_submission, verbose, iterations)
#      28 def create_submission(train, test, path_to_sample_submission, params, cols, path_to_submission, verbose=1, iterations=1000):
#      29     lgb_train = lgb.Dataset(train[cols], train["is_listened"])
# ---> 30     model_lgm = lgb.train(params, lgb_train, iterations, verbose_eval=verbose)
#      31
#      32     lgbm_preds = model_lgm.predict(test[cols])
#
# /home/tsdaemon/anaconda3/lib/python3.6/site-packages/lightgbm-0.1-py3.6.egg/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, callbacks)
#     178                                     evaluation_result_list=None))
#     179
# --> 180         booster.update(fobj=fobj)
#     181
#     182         evaluation_result_list = []
#
# /home/tsdaemon/anaconda3/lib/python3.6/site-packages/lightgbm-0.1-py3.6.egg/lightgbm/basic.py in update(self, train_set, fobj)
#    1353             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1354                 self.handle,
# -> 1355                 ctypes.byref(is_finished)))
#    1356             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1357             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
mlgbm.feature_score(fs,cols)
